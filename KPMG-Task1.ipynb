# %%
#Task 1: Data Quality Assessment

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows',False)

# %%
#Deal with "Transactions" sheet

# %%
trans=pd.read_excel("/Users/xuqinyi/Desktop/KPMG Data Analytics Virtual/KPMG.xlsx",sheet_name='Transactions')

# %%
trans
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 1                   2           3         3120       2017-05-21           1.0
# 2                   3          37          402       2017-10-16           0.0
# 3                   4          88         3135       2017-08-31           0.0
# 4                   5          78          787       2017-10-01           1.0
# 5                   6          25         2339       2017-03-08           1.0
# 6                   7          22         1542       2017-04-21           1.0
# 7                   8          15         2459       2017-07-15           0.0
# 8                   9          67         1305       2017-08-10           0.0
# ...               ...         ...          ...              ...           ...
# 19991           19992          11         1374       2017-09-14           0.0
# ...

# %%
trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             19640 non-null  float64
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  float64
#  12  product_first_sold_date  19803 non-null  float64
# ...

# %%
#Transfer to datetime
trans['product_first_sold_date']=pd.to_datetime(trans['product_first_sold_date'],unit='D',origin='1899-12-30')

# %%
trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             19640 non-null  float64
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  float64
#  12  product_first_sold_date  19803 non-null  datetime64[ns]
# ...

# %%
trans.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost product_first_sold_date
# ...

# %%
trans.describe()
# Out:
#        transaction_id   product_id   customer_id  online_order    list_price  \
# count    20000.000000  20000.00000  20000.000000  19640.000000  20000.000000
# mean     10000.500000     45.36465   1738.246050      0.500458   1107.829449
# std       5773.647028     30.75359   1011.951046      0.500013    582.825242
# min          1.000000      0.00000      1.000000      0.000000     12.010000
# 25%       5000.750000     18.00000    857.750000      0.000000    575.270000
# 50%      10000.500000     44.00000   1736.000000      1.000000   1163.890000
# 75%      15000.250000     72.00000   2613.000000      1.000000   1635.300000
# max      20000.000000    100.00000   5034.000000      1.000000   2091.470000
#
#        standard_cost
# count   19803.000000
# mean      556.046951
# std       405.955660
# min         7.210000
# 25%       215.140000
# 50%       507.580000
# 75%       795.100000
# max      1759.850000

# %%
#Missing Value
trans.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
#Duplicate check
dup=trans.duplicated()
trans[dup].sum()
# Out:
# transaction_id    0.0
# product_id        0.0
# customer_id       0.0
# online_order      0.0
# order_status      0.0
# brand             0.0
# product_line      0.0
# product_class     0.0
# product_size      0.0
# list_price        0.0
# standard_cost     0.0
# dtype: float64

# %%
#trans.to_excel("/Users/xuqinyi/Desktop/KPMG Data Analytics Virtual/Clean KPMG Data.xlsx", sheet_name="Transactions")

# %%
#New_customer sheet

# %%
new_customer=pd.read_excel("/Users/xuqinyi/Desktop/KPMG Data Analytics Virtual/KPMG.xlsx",sheet_name='NewCustomerList')

# %%
new_customer.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...  state    country  \
# 0      Mass Customer                  N      Yes  ...    QLD  Australia
# ...

# %%
new_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    datetime64[ns]
#  5   job_title                            894 non-null    object
#  6   job_industry_category                835 non-null    object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   int64
# ...

# %%
col=['Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20']
new_customer.drop(col,axis=1,inplace=True)

# %%
new_customer.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure              address  \
# 0      Mass Customer                  N      Yes      14     45 Shopko Center
# ...

# %%
new_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    datetime64[ns]
#  5   job_title                            894 non-null    object
#  6   job_industry_category                835 non-null    object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   int64
# ...

# %%
new_customer.describe()
# Out:
#        past_3_years_bike_related_purchases       tenure     postcode  \
# count                          1000.000000  1000.000000  1000.000000
# mean                             49.836000    11.388000  3019.227000
# std                              27.796686     5.037145   848.895767
# min                               0.000000     0.000000  2000.000000
# 25%                              26.750000     7.000000  2209.000000
# 50%                              51.000000    11.000000  2800.000000
# 75%                              72.000000    15.000000  3845.500000
# max                              99.000000    22.000000  4879.000000
#
#        property_valuation         Rank        Value
# count         1000.000000  1000.000000  1000.000000
# mean             7.397000   498.819000     0.881714
# std              2.758804   288.810997     0.293525
# min              1.000000     1.000000     0.340000
# 25%              6.000000   250.000000     0.649531
# ...

# %%
new_customer.isnull().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Rank                                     0
# Value                                    0
# dtype: int64

# %%
new_customer.duplicated().sum()
# Out:
# 0

# %%
new_customer['gender'].value_counts()
# Out:
# Female    513
# Male      470
# U          17
# Name: gender, dtype: int64

# %%
new_customer['gender'].replace('U','Unknown',inplace=True)

# %%
new_customer['gender'].value_counts()
# Out:
# Female     513
# Male       470
# Unknown     17
# Name: gender, dtype: int64

# %%
#Calculating the age of new customers
new_customer["Age"]=pd.to_datetime("today").year-new_customer["DOB"].dt.year

# %%
print(new_customer["Age"])
# Out:
# 0      65.0
# 1      52.0
# 2      48.0
# 3      43.0
# 4      57.0
# 5      71.0
# 6      46.0
# 7      50.0
# 8      50.0
# 9      37.0
# 10     27.0
# 11     23.0
#        ...
# 988    79.0
# 989    77.0
# 990    68.0
# 991    48.0
# 992    49.0
# 993    63.0
# 994    32.0
# 995    63.0
# 996    21.0
# 997    68.0
# 998    70.0
# 999    67.0
# Name: Age, Length: 1000, dtype: float64

# %%
new_customer["Age"].value_counts()
# Out:
# 48.0    29
# 44.0    27
# 49.0    27
# 46.0    27
# 61.0    26
# 47.0    24
# 41.0    23
# 28.0    23
# 66.0    22
# 56.0    22
# 71.0    21
# 50.0    21
#         ..
# 39.0     9
# 78.0     8
# 37.0     8
# 36.0     8
# 79.0     8
# 80.0     8
# 76.0     7
# 74.0     7
# 33.0     6
# 38.0     5
# 73.0     4
# 20.0     3
# Name: Age, Length: 65, dtype: int64

# %%
#new_customer.to_excel("/Users/xuqinyi/Desktop/KPMG Data Analytics Virtual/Clean KPMG Data.xlsx", sheet_name="NewCustomerList")

# %%
#Customer Demographic

# %%
cus_demo=pd.read_excel("/Users/xuqinyi/Desktop/KPMG Data Analytics Virtual/KPMG.xlsx",sheet_name='CustomerDemographic')

# %%
cus_demo.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator  \
# 0                Health      Mass Customer                  N
# 1    Financial Services      Mass Customer                  N
# ...

# %%
cus_demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4000 non-null   int64
#  1   first_name                           4000 non-null   object
#  2   last_name                            3875 non-null   object
#  3   gender                               4000 non-null   object
#  4   past_3_years_bike_related_purchases  4000 non-null   int64
#  5   DOB                                  3913 non-null   datetime64[ns]
#  6   job_title                            3494 non-null   object
#  7   job_industry_category                3344 non-null   object
#  8   wealth_segment                       4000 non-null   object
#  9   deceased_indicator                   4000 non-null   object
#  10  default                              3698 non-null   object
# ...

# %%
cus_demo=cus_demo.drop('default',axis=1)

# %%
cus_demo.describe()
# Out:
#        customer_id  past_3_years_bike_related_purchases       tenure
# count  4000.000000                          4000.000000  3913.000000
# mean   2000.500000                            48.890000    10.657041
# std    1154.844867                            28.715005     5.660146
# min       1.000000                             0.000000     1.000000
# 25%    1000.750000                            24.000000     6.000000
# 50%    2000.500000                            48.000000    11.000000
# 75%    3000.250000                            73.000000    15.000000
# max    4000.000000                            99.000000    22.000000

# %%
cus_demo.isnull().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
cus_demo.duplicated().sum()
# Out:
# 0

# %%
cus_demo["gender"].value_counts()
# Out:
# Female    2037
# Male      1872
# U           88
# M            1
# Femal        1
# F            1
# Name: gender, dtype: int64

# %%
cus_demo["gender"].replace('F','Female',inplace=True)
cus_demo["gender"].replace('Femal','Female',inplace=True)
cus_demo["gender"].replace('M','Male',inplace=True)
cus_demo["gender"].replace('U','Unknown',inplace=True)

# %%
cus_demo["gender"].value_counts()
# Out:
# Female     2039
# Male       1873
# Unknown      88
# Name: gender, dtype: int64

# %%
cus_demo["Age"]=pd.to_datetime("today").year-cus_demo["DOB"].dt.year

# %%
cus_demo["Age"].value_counts()
# Out:
# 44.0     217
# 45.0     204
# 48.0     152
# 46.0     152
# 42.0     123
# 49.0     122
# 43.0     118
# 36.0     114
# 47.0     114
# 63.0      94
# 37.0      91
# 27.0      90
#         ...
# 22.0      42
# 40.0      41
# 39.0      40
# 21.0      34
# 69.0      19
# 20.0       6
# 87.0       1
# 179.0      1
# 78.0       1
# 91.0       1
# 82.0       1
# 79.0       1
# Name: Age, Length: 56, dtype: int64

# %%
#cus_demo.to_excel("/Users/xuqinyi/Desktop/KPMG Data Analytics Virtual/Clean KPMG Data.xlsx", sheet_name="CustomerDemographic")

# %%
#Customer Address

# %%
cus_address=pd.read_excel("/Users/xuqinyi/Desktop/KPMG Data Analytics Virtual/KPMG.xlsx",sheet_name='CustomerAddress')

# %%
cus_address.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         3999 non-null   int64
#  1   address             3999 non-null   object
#  2   postcode            3999 non-null   int64
#  3   state               3999 non-null   object
#  4   country             3999 non-null   object
#  5   property_valuation  3999 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 187.6+ KB

# %%
cus_address.describe()
# Out:
#        customer_id     postcode  property_valuation
# count  3999.000000  3999.000000         3999.000000
# mean   2003.987997  2985.755939            7.514379
# std    1154.576912   844.878364            2.824663
# min       1.000000  2000.000000            1.000000
# 25%    1004.500000  2200.000000            6.000000
# 50%    2004.000000  2768.000000            8.000000
# 75%    3003.500000  3750.000000           10.000000
# max    4003.000000  4883.000000           12.000000

# %%
cus_address.groupby('state').count()
# Out:
#                  customer_id  address  postcode  country  property_valuation
# state
# NSW                     2054     2054      2054     2054                2054
# New South Wales           86       86        86       86                  86
# QLD                      838      838       838      838                 838
# VIC                      939      939       939      939                 939
# Victoria                  82       82        82       82                  82

# %%
cus_address['state'].replace('New South Wales','NSW',inplace=True)
cus_address['state'].replace('Victoria','VIC',inplace=True)

# %%
cus_address.groupby('state').count()
# Out:
#        customer_id  address  postcode  country  property_valuation
# state
# NSW           2140     2140      2140     2140                2140
# QLD            838      838       838      838                 838
# VIC           1021     1021      1021     1021                1021

# %%
# The number of customer does not match the number of customer in Customer demograohic list

# %%
with pd.ExcelWriter('/Users/xuqinyi/Desktop/KPMG Data Analytics Virtual/Clean KPMG Data.xlsx') as writer:  
        trans.to_excel(writer, sheet_name='Transactions')
        new_customer.to_excel(writer, sheet_name='NewCustomerList')
        cus_demo.to_excel(writer, sheet_name='CustomerDemographic')
        cus_address.to_excel(writer, sheet_name='CustomerAddress')
        #cus_2.to_excel(writer, sheet_name='Raw Data')

# %%
#By overviewing the data to see is there any wield place of data, deleting some unnecessary column
#Basically, for each sheet, we started with getting know the data information of each column, and check whether there is a inappropriate data type of the column given the column name;
#Then we check the missing value and duplicate with the data
#For some columns, replace some incomplicated string with the correct one.
#Conducting some basic logic check, for example the age of the customer;
